# %% [markdown]
# <a href="https://colab.research.google.com/github/nastaran-farhadi/LLM-BBAC/blob/main/implementing_bbac_in_gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker
# !pip install pandas
# !pip install google-generativeai
# !pip install python-magic
# !pip install unstructured
# !pip install chromadb
# !pip install langchain-community
# !pip install python-dotenv
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nastaran-farhadi/LLM-BBAC.git /content/drive/MyDrive/LLM-BBAC
# Out:
# fatal: destination path '/content/drive/MyDrive/LLM-BBAC' already exists and is not an empty directory.

# %%
cd /content/drive/MyDrive/LLM-BBAC
# Out:
# /content/drive/MyDrive/LLM-BBAC

# %%
# !ls
# Out:
# attributes_gen.py  data		evaluate.ipynb	      prompt_gen.py  query_data.py
# chroma		   data_gen.py	generate_database.py  __pycache__    README.md

# %%
# !python data_gen.py
# Out:
# Employee data has been generated and saved to data.txt.

# %%
# !python3 attributes_gen.py
# Out:
# RBAC roles and access data successfully written to /content/drive/MyDrive/LLM-BBAC/data/Behavior/BBAC_attributes.csv

# %%
import google.generativeai as genai

# Configure Gemini
genai.configure(api_key="AIzaSyC2AszMTHSy2ZdUdtfMTTa03GyiWz9_eco")

# Initialize the model
GEMINI_MODEL = genai.GenerativeModel('gemini-2.0-pro-exp')

# %%
# !pip install langchain-google-genai
import os
from langchain_google_genai import ChatGoogleGenerativeAI
os.environ["GOOGLE_API_KEY"] = "AIzaSyC2AszMTHSy2ZdUdtfMTTa03GyiWz9_eco"  # Set environment variable
model = ChatGoogleGenerativeAI(model="gemini-2.0-pro-exp")  # No need to pass the key here
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.4 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.16 which is incompatible.
# ...

# %%
# !python3 generate_database.py
# Out:
# 2025-02-27 09:53:38.537255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740650018.564603    2155 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740650018.572112    2155 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-27 09:53:38.597338: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install langchain-google-genai

# %%
# !pip install langchain-community

# %%
# !python query_data.py "John Doe" "What is Tony Clark's salary?" "Working Hours" "In the Department"
# Out:
# /content/drive/MyDrive/LLM-BBAC/query_data.py:74: LangChainDeprecationWarning: The method `BaseChatModel.predict` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response_text = model.predict(prompt)
#
# Response: Tony Clark's salary is $111179.36.
#
# Source: database.txt

# %%
# !python3 /content/drive/MyDrive/LLM-RBAC/query_data.py "John Doe" "what is Anne Hampton Salary?"

# %%
from query_data import get_response
import re
import time
import subprocess

# Initialize counters
true_positive = 0    # Correctly allowed access
false_negative = 0   # Wrongly denied access
false_positive = 0   # Irrelevant for this test (no unauthorized access)
true_negative = 0    # Irrelevant for this test (no unauthorized access)

# Parameters for the test
num_tests = 5  # Number of times to run the query
salary_pattern = r"\$111179\.36"   # Regex for salary format

for _ in range(num_tests):
    # Run the query for John Doe (admin with valid access)
    cmd = [
        "John Doe",
        "What is Tony Clark's Salary?",
        "Working Hours",
        "In the Department"
    ]
    result = subprocess.run(['python3', 'query_data.py'] + cmd, capture_output=True, text=True)
    response = result.stdout
    print(f"Response from query_data.py: {response.strip()}")  # Print the response for debugging
    # Check if salary is returned
    if re.search(salary_pattern, response):
        true_positive += 1  # System allowed access (correct)
    else:
        false_negative += 1  # System denied access (wrong)
        print(f"False Negative: {response.strip()}")  # Print false negatives for debugging

# Calculate metrics (focus on TP and FN)
precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 1.0
recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0.0
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

# Print results
print(f"""
Access Control Evaluation (John Doe as Administrator):
-----------------------------------------------------
True Positives (Allowed Correctly): {true_positive}/{num_tests}
False Negatives (Denied Incorrectly): {false_negative}/{num_tests}

Precision: {precision:.2f} (No FP in this test)
Recall:    {recall:.2f} (Correct allowances over total valid accesses)
F1 Score:  {f1:.2f}/1.00
""")
# Out:
# Response from query_data.py: Response: Tony Clark's salary is $111,179.36.
#
# Source: database.txt
# False Negative: Response: Tony Clark's salary is $111,179.36.
#
# Source: database.txt
# Response from query_data.py: Response: Tony Clark's Salary is $111179.36.
#
# Source: database.txt
# Response from query_data.py:
# False Negative:
# Response from query_data.py:
# False Negative:
# Response from query_data.py:
# False Negative:
#
# Access Control Evaluation (John Doe as Administrator):
# -----------------------------------------------------
# True Positives (Allowed Correctly): 1/5
# False Negatives (Denied Incorrectly): 4/5
#
# Precision: 1.00 (No FP in this test)
# Recall:    0.20 (Correct allowances over total valid accesses)
# F1 Score:  0.33/1.00

# %% [markdown]
# up to here

# %%
from query_data import get_response
import re
import time
import subprocess

# Initialize counters
true_positive = 0
false_negative = 0
false_positive = 0
true_negative = 0

# Parameters for the test
num_tests = 5  # Number of times to run each query
salary_pattern = r"\$111179\.36"
access_denied_pattern = r"Access Denied"  # Pattern for denied access messages

# ... (Your existing loop for true positive/false negative cases)

# False Positive Test
for _ in range(num_tests):
    # Run query with a user who should not have access to salary
    response = get_response("Sophia Miller", "What is Tony Clark's Salary?", "Night Shift", "Home")  # Replace with your unauthorized user
    if re.search(salary_pattern, response):  # Incorrectly allowed access
        false_positive += 1
    else:  # Correctly denied access
        true_negative += 1
    time.sleep(30)
# True Negative Test
for _ in range(num_tests):
    # Run query with a user who should not have access to other sensitive info
    response = get_response("Sophia Miller", "What is Tony Clark's Salary?", "Night Shift", "Home") # Replace with your sensitive info query
    if re.search(access_denied_pattern, response):
        true_negative += 1
    else:
        false_positive += 1
    time.sleep(30)

# Print results
print(f"""
Access Control Evaluation (John Doe as Administrator):
-----------------------------------------------------
false_positive (Allowed Correctly): {false_positive}/{num_tests}
true_negative (Denied Incorrectly): {true_negative}/{num_tests}
""")
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# <ipython-input-33-d60c74733a03> in <cell line: 0>()
#      20 for _ in range(num_tests):
#      21     # Run query with a user who should not have access to salary
# ---> 22     response = get_response("Sophia Miller", "What is Tony Clark's Salary?", "Night Shift", "Home")  # Replace with your unauthorized user
#      23     if re.search(salary_pattern, response):  # Incorrectly allowed access
#      24         false_positive += 1
#
# /content/drive/MyDrive/LLM-BBAC/query_data.py in get_response(person_name, query_text, query_time, query_location)
#      72     )
# ...

# %%
from query_data import get_response
import re
import time

# HR Manager Test
true_positive = 0
for _ in range(5):
    response = get_response("Administrator", "What is Anne Hampton salary and address?")
    if re.search(r"40,600\.26|40600\.26", response):
        true_positive += 1
    time.sleep(20)  # Increase delay to 5 seconds
print(f"HR Manager Success Rate: {true_positive/5*100}%")  #Corrected calculation to divide by 5

# %%
from query_data import get_response
import re
import time

# HR Manager Test
true_positive = 0
false_positive = 0
false_negative = 0

for _ in range(5):
    response = get_response("Administrator", "What is Anne Hampton salary and address?")
    if re.search(r"40,600\.26|40600\.26", response):
        true_positive += 1
    else:
        false_negative += 1  # Increment false negative if salary not found
    time.sleep(20)  # Increase delay to 10 seconds

# Assuming you have a way to identify false positives (e.g., using a different query)
# Replace this with your logic for identifying false positives:
# For example, if you have another query where the salary shouldn't be present:
for _ in range(5):
     response = get_response("Administrator", "What is Anne Hampton salary and address?")
     if re.search(r"40,600\.26|40600\.26", response):
        false_positive += 1
     time.sleep(20)

# Calculate precision, recall, and F1 score
if true_positive + false_positive == 0:
    precision = 0  # Avoid division by zero
else:
    precision = true_positive / (true_positive + false_positive)

if true_positive + false_negative == 0:
    recall = 0  # Avoid division by zero
else:
    recall = true_positive / (true_positive + false_negative)

if precision + recall == 0:
    f1_score = 0  # Avoid division by zero
else:
    f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Adminstrator: {true_positive/5*100}%")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
